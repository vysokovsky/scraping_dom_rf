# %%
import requests
import pandas as pd
import json
import time

# %% [markdown]
# ## Данные по кредитам
# [дом.рф/ипотечное кредитование](https://наш.дом.рф/аналитика/ипотечное_кредитование/детали/таблица)

# %%
def get_payload(date):
    return "{{\"regionId\":1,\"reportingPeriod\":\"{0}\",\"currency\":\"ALL\",\"creditType\":\"total\",\"periodType\":\"month\",\"regionWithAutonomous\":\"yes\"}}".format(date)

# %%
def get_df(date):
    url = 'https://xn--80az8a.xn--d1aqf.xn--p1ai/аналитика/apid/mortgage/api/table/data'
    headers = {'accept': 'application/json', 'content-type': 'application/json'}
    success = False
    
    while not success:
        print(f'Making request for {date}... ', end='')
        r = requests.post(url, data=get_payload(date), headers=headers)
        if r.status_code == 200:
            print('OK')
            success = True
        else:
            print(f'\nRequest failed with {r.status_code} code. Retry in 30 seconds... ')
            time.sleep(30)
            
    print('Checking data quality... ', end='')
    data = json.loads(r.text)['data']['body']
    if data:
        print('OK')
        df = pd.DataFrame(data).sort_values('sortOrder')
        df['period'] = date
        df = df.set_index(['id', 'period'])
        return df
    else:
        print(f'WARNING: data for {date} period is not available.')
        return None

# %%
date_range = pd.date_range(start='2019-01-01', end='2022-12-01', freq='MS')

# %%
df_cred = []

# %%
for date in date_range:
    dt = str(date.date())
    df_cred.append(get_df(dt))

# %%
df_cred = pd.concat(df_cred)

# %%
df_cred
# Out:
#                                          name     fo  creditCount  \
# id   period
# 1    2019-01-01          Российская Федерация  False       81.054
# 17   2019-01-01                Центральный ФО   True       20.599
# 1758 2019-01-01          Белгородская область  False        0.715
# 1759 2019-01-01              Брянская область  False        0.611
# 1760 2019-01-01          Владимирская область  False        0.701
# ...                                       ...    ...          ...
# 1101 2022-12-01              Амурская область  False        1.111
# 1184 2022-12-01           Магаданская область  False        0.214
# 1106 2022-12-01           Сахалинская область  False        0.565
# 1102 2022-12-01  Еврейская автономная область  False        0.147
# 1185 2022-12-01    Чукотский автономный округ  False        0.089
#
#                  creditCountPct  creditCountDelta  creditCountDeltaPct  \
# id   period
# 1    2019-01-01      100.000000             3.007              3.85281
# 17   2019-01-01       25.413900             1.680              8.87996
# 1758 2019-01-01        0.882128             0.082             12.95420
# 1759 2019-01-01        0.753818             0.072             13.35810
# 1760 2019-01-01        0.864856             0.043              6.53495
# ...                         ...               ...                  ...
# 1101 2022-12-01        0.630376            -0.094             -7.80083
# 1184 2022-12-01        0.121423            -0.130            -37.79070
# 1106 2022-12-01        0.320578            -0.226            -28.57140
# 1102 2022-12-01        0.083407            -0.002             -1.34228
# 1185 2022-12-01        0.050498             0.022             32.83580
#
#                  creditAmount  creditAmountPct  creditAmountDelta  \
# id   period
# 1    2019-01-01       173.119       100.000000          24.803701
# 17   2019-01-01        56.585        32.685600           9.611740
# 1758 2019-01-01         1.283         0.741109           0.226000
# 1759 2019-01-01         1.103         0.637134           0.304000
# 1760 2019-01-01         1.234         0.712804           0.171000
# ...                       ...              ...                ...
# 1101 2022-12-01         5.195         0.745475           0.655000
# 1184 2022-12-01         0.993         0.142494          -0.314000
# 1106 2022-12-01         2.763         0.396487          -0.718000
# 1102 2022-12-01         0.493         0.070745           0.075000
# 1185 2022-12-01         0.401         0.057543           0.146000
#
#                  creditAmountDeltaPct  wghtdAvgRate  wghtdAvgRateDelta  \
# id   period
# 1    2019-01-01               16.7237          9.88               0.03
# 17   2019-01-01               20.4621          9.89               0.04
# 1758 2019-01-01               21.3813          9.82               0.10
# 1759 2019-01-01               38.0476          9.76               0.03
# 1760 2019-01-01               16.0865          9.86               0.04
# ...                               ...           ...                ...
# 1101 2022-12-01               14.4273          6.08               0.29
# 1184 2022-12-01              -24.0245          6.20               0.69
# 1106 2022-12-01              -20.6263          6.08              -0.01
# 1102 2022-12-01               17.9426          6.32              -1.02
# 1185 2022-12-01               57.2549          6.81               1.06
#
#                  sortOrder
# id   period
# 1    2019-01-01          1
# 17   2019-01-01          2
# 1758 2019-01-01          3
# 1759 2019-01-01          4
# 1760 2019-01-01          5
# ...                    ...
# 1101 2022-12-01         94
# 1184 2022-12-01         95
# 1106 2022-12-01         96
# 1102 2022-12-01         97
# 1185 2022-12-01         98
#
# [4368 rows x 13 columns]

# %% [markdown]
# ## Статистика по жилищному строительству
# [дом.рф/жилищное строительство](https://наш.дом.рф/аналитика/показатели_жилищного_строительства)

# %%
def get_url(year, month,*,fo=None, rg=None):
    url = 'https://наш.дом.рф/аналитика/api/consolidated/housing_constructor/total'
    param = f'?repYear={year}&repMonth={month}' + (f'&foCd={fo}' if fo else '') + (f'&regionCode={rg}' if rg else '')
    return url + param

# %%
def get_json(year, month, *, fo=None, rg=None):
    success = False
    while not success:
        print(f'Making request for year {year}, month {month}, FD {fo}, region {rg}... ', end='')
        r = requests.get(get_url(year, month, fo=fo, rg=rg))
        if r.status_code == 200:
            print('OK')
            success = True
        else:
            print(f'\nRequest failed with {r.status_code} code. Retry in 30 seconds... ')
            time.sleep(30)
            
    print('Checking data quality... ', end='')
    data = json.loads(r.text)['data']
    if data:
        print('OK')
        j = data[0]
        j['period'] = f"{year}-{month:02}-01"
        j['id'] = 1000 if fo is None and rg is None else (fo if rg is None else rg)
        return j
    else:
        print(f'WARNING: data for these parameters is not available.')
        return None

# %%
with open('regions.json') as f:
    regions = json.load(f)

# %%
date_range = pd.date_range(start='2019-01-01', end='2022-12-01', freq='MS')

# %%
full_json = []

# %%
for date in date_range:
    year = date.date().year
    month = date.date().month

#     SUBJECTS
    for fd in regions['regionsByFo']:
        for rg in fd['regions']:
            fo_code = fd['federalDistrict']['foCd']
            rg_code = rg['regionCd']
            rg_name = rg['regionShortDesc']
            
            j = get_json(year, month, rg=rg_code, fo=fo_code)
            if j is not None:
                j['name'] = rg_name
                full_json.append(j)
                
#     FEDERAL DISTRICTS
    for fd in regions['regionsByFo']:
        fo_code = fd['federalDistrict']['foCd']
        fo_name = fd['federalDistrict']['foDesc']

        j = get_json(year, month, fo=fo_code)
        if j is not None:
            j['name'] = fo_name
            full_json.append(j)

#     COUNTRY
    j = get_json(year, month)
    if j is not None:
        j['name'] = 'Российская Федерация'
        full_json.append(j)

# %%
df_stat = pd.DataFrame(full_json)

# %%
df_stat
# Out:
#     repYear  repMonth   type subject           subjectDesc  devCnt  rnsCnt  \
# 0      2019        10  total     100  Российская Федерация      12      20
# 1      2019        10  total     100  Российская Федерация       7      17
# 2      2019        10  total     100  Российская Федерация       1       1
# 3      2019        10  total     100  Российская Федерация      44      63
# 4      2019        10  total     100  Российская Федерация      11      27
# ..      ...       ...    ...     ...                   ...     ...     ...
# 85     2019        10  total     100  Российская Федерация     386     809
# 86     2019        10  total     100  Российская Федерация     289     707
# 87     2019        10  total     100  Российская Федерация    1041    2261
# 88     2019        10  total     100  Российская Федерация     461     942
# 89     2019        10  total     100  Российская Федерация    3772    7791
#
#     rpdCnt  objCnt  livingSquareSum  ...  zosgLivingElemSum  \
# 0       20      21            124.0  ...                1.0
# 1       17      17            120.0  ...                2.3
# 2        1       1              0.6  ...                NaN
# 3       63      84            853.0  ...               10.3
# 4       29      49            285.0  ...                4.5
# ..     ...     ...              ...  ...                ...
# 85     864    1260           9075.0  ...              112.6
# 86     724     862           7881.0  ...               82.4
# 87    2320    3392          40392.0  ...              531.7
# 88     973    1819          15096.0  ...              190.2
# 89    8018   11588         115828.0  ...             1526.1
#
#     nonguarantyDevCnt  nonguarantyRnsCnt  nonguarantyRpdCnt  \
# 0                   7                  9                  9
# 1                   2                  2                  2
# 2                   1                  1                  1
# 3                   3                  4                  4
# 4                   5                  5                  5
# ..                ...                ...                ...
# 85                111                209                215
# 86                 62                111                112
# 87                221                340                338
# 88                124                242                247
# 89                867               1479               1495
#
#     nonguarantyObjCnt  nonguarantyLivingSquareSum  nonguarantyLivingElemSum  \
# 0                  10                        49.0                       1.0
# 1                   2                        13.0                       0.2
# 2                   1                         0.6                       0.0
# 3                   7                        59.0                       1.2
# 4                  14                        60.0                       1.4
# ..                ...                         ...                       ...
# 85                332                      2024.0                      38.6
# 86                139                      1201.0                      22.1
# 87                565                      3763.0                      69.3
# 88                375                      3261.0                      69.8
# 89               2150                     17273.0                     352.9
#
#         period    id                  name
# 0   2019-10-01    28      Амурская область
# 1   2019-10-01    75    Забайкальский край
# 2   2019-10-01    41       Камчатский край
# 3   2019-10-01    25       Приморский край
# 4   2019-10-01     3    Республика Бурятия
# ..         ...   ...                   ...
# 85  2019-10-01   107          Сибирский ФО
# 86  2019-10-01   106          Уральский ФО
# 87  2019-10-01   101        Центральный ФО
# 88  2019-10-01   103              Южный ФО
# 89  2019-10-01  1000  Российская Федерация
#
# [90 rows x 32 columns]

# %%
df_stat = df_stat.set_index(['id', 'period'])

# %%
df_stat = df_stat.drop(columns=['repYear', 'repMonth', 'type', 'subject', 'subjectDesc'])

# %%
col_list = df_stat.columns.to_list()
reordered = col_list[-1:] + col_list[0:-1]
df_stat = df_stat[reordered]

# %%
with pd.ExcelWriter('data.xlsx') as f:
    df_cred.to_excel(f, sheet_name='credits')
    df_stat.to_excel(f, sheet_name='sources')
